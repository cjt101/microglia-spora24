# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
temp_data = pd.read_excel('Temperature, Time to Clear (magnitude=10).xlsx', header=17)
temp_data.head()
# Out:
#    temperature  ticks  Average Ticks to Clear 10 Damaged Neurons  temp  \
# 0         36.0    916                                    1346.67  36.0
# 1         36.0    941                                    1267.31  36.1
# 2         36.0    820                                    1261.10  36.2
# 3         36.0   1336                                    1228.28  36.3
# 4         36.0   1006                                    1229.38  36.4
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0     1346.67         NaN         NaN         NaN         NaN         NaN
# 1     1267.31         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    ...  Unnamed: 4091  Unnamed: 4092  Unnamed: 4093  Unnamed: 4094  \
# ...

# %%
temp_data = temp_data.filter(['temperature', 'ticks'])
temp_data.rename(columns={'ticks':'Ticks'}, inplace=True)
temp_data.head()
# Out:
#    temperature  Ticks
# 0         36.0    916
# 1         36.0    941
# 2         36.0    820
# 3         36.0   1336
# 4         36.0   1006

# %%
# don't know if this data is complete, so checking to see all groups
# have the same number of trials
print(temp_data.groupby(['temperature']).size().to_string())
# Out:
# temperature
# 36.0    100
# 36.1    100
# 36.2    100
# 36.3    100
# 36.4    100
# 36.5    100
# 36.6    100
# 36.7    100
# 36.8    100
# 36.9    100
# 37.0    100
# 37.1    100
# 37.2    100
# 37.3    100
# 37.4    100
# 37.5    100
# 37.6    100
# 37.7    100
# 37.8    100
# 37.9    100
# 38.0    100
# 38.1    100
# 38.2    100
# 38.3    100
# 38.4    100
# 38.5    100
# 38.6    100
# 38.7    100
# 38.8    100
# 38.9    100
# 39.0    100
# 39.1    100
# 39.2    100
# 39.3    100
# 39.4    100
# 39.5    100
# 39.6    100
# 39.7    100
# 39.8    100
# 39.9    100
# 40.0    100

# %%
temp_data.groupby('temperature').mean()
# Out:
#                Ticks
# temperature
# 36.0         1346.67
# 36.1         1267.31
# 36.2         1261.10
# 36.3         1228.28
# 36.4         1229.38
# 36.5         1051.61
# 36.6         1090.44
# 36.7         1060.89
# 36.8          994.11
# 36.9         1021.35
# 37.0          939.68
# 37.1          913.04
# 37.2          892.29
# 37.3          905.06
# 37.4          902.91
# 37.5          868.38
# 37.6          919.73
# 37.7          903.40
# 37.8          892.43
# 37.9          913.48
# 38.0          909.73
# 38.1          829.09
# 38.2          885.18
# 38.3          917.07
# 38.4          903.13
# 38.5          908.85
# 38.6          870.89
# 38.7          858.32
# 38.8          906.93
# 38.9          900.43
# 39.0          960.04
# 39.1          918.74
# 39.2          938.10
# 39.3          866.36
# 39.4          910.33
# 39.5          921.54
# 39.6          975.72
# 39.7          924.52
# 39.8          957.87
# 39.9          886.19
# 40.0          871.33

# %%
plt.style.use('bmh')
plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.dpi'] = 300

(
    temp_data
    .groupby('temperature')
    .mean()
    .plot()
)

plt.legend(['Average over 10 trials'])
#plt.title('Average Time Taken to Clear Damaged Neurons (magnitude * 10)', pad=20)
plt.xlabel('temperature (C\xb0)')
plt.ylabel('ticks')
plt.ylim(700, 1400)
plt.xlim(35.9, 40.1)

plt.savefig('temp-ver-1-1.png', bbox_inches='tight')

# %%
# alternate graph where y-axis starts at 0 instead of 700
(
    temp_data
    .groupby('temperature')
    .mean()
    .plot()
)

plt.legend(['Average over 10 trials'])
#plt.title('Average Time Taken to Clear Damaged Neurons (magnitude * 10)', pad=20)
plt.ylabel('ticks')
plt.xlabel('temperature (C\xb0)')
plt.ylim(0, 1400)
plt.xlim(35.9, 40.1)

# Uncomment to save
# plt.savefig('temp-ver-2-1.png', bbox_inches='tight')
# Out:
# (35.9, 40.1)

# %%
eat_data = pd.read_excel('Eat Probability, Time to Clear.xlsx', header=23)
eat_data.head()
# Out:
#    eat-probability  Unnamed: 1  Unnamed: 2  avg-per-probability  \
# 0             10.0        4213         NaN              7470.04
# 1              NaN        4213         NaN              6525.12
# 2             10.0        5743         NaN              6021.36
# 3              NaN        5743         NaN              5686.78
# 4             10.0        9325         NaN              5343.08
#
#    eat-probability.1  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0               10.0         NaN         NaN         NaN         NaN
# 1               11.0         NaN         NaN         NaN         NaN
# 2               12.0         NaN         NaN         NaN         NaN
# 3               13.0         NaN         NaN         NaN         NaN
# 4               14.0         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  ...  Unnamed: 9091  Unnamed: 9092  Unnamed: 9093  \
# 0         NaN  ...            NaN            NaN            NaN
# ...

# %%
# weird data duplication happened, removing rows that have
# no value for eat-probability
eat_data = eat_data[eat_data['eat-probability'].notnull()]
eat_data.reset_index(inplace=True)
eat_data.rename(columns={'Unnamed: 1':'Ticks'}, inplace=True)
eat_data = eat_data.filter(['eat-probability', 'Ticks'])

eat_data.head()
# Out:
#    eat-probability  Ticks
# 0             10.0   4213
# 1             10.0   5743
# 2             10.0   9325
# 3             10.0   5094
# 4             10.0   6427

# %%
# eat_data.head(51)

# %%
# don't know if this data is complete, so checking to see all groups
# have the same number of trials
# print(eat_data.groupby(['eat-probability']).size().to_string())

# %%
# get min/max for ylabel ranges
print(eat_data.groupby('eat-probability').mean().max())
print(eat_data.groupby('eat-probability').mean().min())
# Out:
# Ticks    7470.04
# dtype: float64
# Ticks    690.02
# dtype: float64

# %%
(
    eat_data
    .groupby('eat-probability')
    .mean()
    .plot()
)

plt.legend(['Average over 50 trials'])
plt.ylabel('ticks')
plt.xlabel('eat probability (%)')
plt.ylim(650, 8000)
plt.xlim(10.0, 100.1)
plt.xticks(np.arange(0, 101, 10))

plt.savefig('eat-prob.png', bbox_inches='tight')

# %%
num_data = pd.read_excel("Num Microglia, Time to Clear.xlsx", header=17)
num_data.head()
# Out:
#    initial-number-microglia  ticks  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                         1   5571         NaN         NaN         NaN
# 1                         1   3233         NaN         NaN         NaN
# 2                         1   7884         NaN         NaN         NaN
# 3                         1   4738         NaN         NaN         NaN
# 4                         1   3973         NaN         NaN         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# 2         NaN         NaN         NaN         NaN         NaN  ...
# 3         NaN         NaN         NaN         NaN         NaN  ...
# 4         NaN         NaN         NaN         NaN         NaN  ...
#
#    Unnamed: 191  Unnamed: 192  Unnamed: 193  Unnamed: 194  Unnamed: 195  \
# ...

# %%
num_data = num_data.filter(['initial-number-microglia', 'ticks'])
num_data.head()
# Out:
#    initial-number-microglia  ticks
# 0                         1   5571
# 1                         1   3233
# 2                         1   7884
# 3                         1   4738
# 4                         1   3973

# %%
# don't know if this data is complete, so checking to see all groups
# have the same number of trials
print(num_data.groupby(['initial-number-microglia']).size().to_string())
# Out:
# initial-number-microglia
# 1     10
# 2     10
# 3     10
# 4     10
# 5     10
# 6     10
# 7     10
# 8     10
# 9     10
# 10    10
# 11    10
# 12    10
# 13    10
# 14    10
# 15    10
# 16    10
# 17    10
# 18    10
# 19    10
# 20    10

# %%
# get min/max for y-value
print(num_data['ticks'].min())
print(num_data['ticks'].max())
# Out:
# 118
# 8558

# %%
plt.scatter(num_data['initial-number-microglia'],
            num_data['ticks'],
            alpha=0.4)

# Uncomment to obtain plot where alpha=1
# plt.scatter(num_data['initial-number-microglia'],
#             num_data['ticks'])

plt.legend([])
plt.ylabel('ticks')
plt.xlabel('number of microglia')
plt.ylim(0, 8750)
plt.xlim(0, 21)
plt.xticks(np.arange(0, 21, 5))
plt.legend().set_visible(False)

plt.savefig('num-glia-alpha.png', bbox_inches='tight')

# Uncomment to save plot where alpha=1
# plt.savefig('num-glia.png', bbox_inches='tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
